# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Everything is working!")
# Out:
# Everything is working!

# %% [markdown]
# # Credit Risk & Default Prediction Model
#
# ## Objective
# Build a machine learning model to predict whether a customer is likely to default on a loan.
#
# ## Dataset
# Home Credit Default Risk Dataset (Kaggle)
#
# ## Machine Learning Model
# Logistic Regression
